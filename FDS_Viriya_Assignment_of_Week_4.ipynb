# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import your dataset which contain at least 2 tables. And then create NaN value in your dataset for practice.

# %%
df = pd.read_csv('/content/application_record.csv',delimiter=',', on_bad_lines='skip')
df2 = pd.read_csv('/content/credit_record.csv',delimiter=',', on_bad_lines='skip')
# Out:
# <ipython-input-119-9e8c734c1775>:1: DtypeWarning: Columns (0,4,5,10,11,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/application_record.csv',delimiter=',', on_bad_lines='skip')
# <ipython-input-119-9e8c734c1775>:2: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/credit_record.csv',delimiter=',', on_bad_lines='skip')

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN  \
# 0  5008804           M            Y               Y            0
# 1  5008805           M            Y               Y            0
# 2  5008806           M            Y               Y            0
# 3  5008808           F            N               Y            0
# 4  5008809           F            N               Y            0
#
#   AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0         427500.0               Working               Higher education
# 1         427500.0               Working               Higher education
# 2         112500.0               Working  Secondary / secondary special
# 3         270000.0  Commercial associate  Secondary / secondary special
# 4         270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment     -12005         -4542
# ...

# %%
df2.head()
# Out:
#         ID MONTHS_BALANCE STATUS
# 0  5001711            0.0      X
# 1  5001711           -1.0      0
# 2  5001711           -2.0      0
# 3  5001711           -3.0      0
# 4  5001712            0.0      C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851735 entries, 0 to 851734
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   851735 non-null  object
#  1   CODE_GENDER          851735 non-null  object
#  2   FLAG_OWN_CAR         851735 non-null  object
#  3   FLAG_OWN_REALTY      851735 non-null  object
#  4   CNT_CHILDREN         851735 non-null  object
#  5   AMT_INCOME_TOTAL     851735 non-null  object
#  6   NAME_INCOME_TYPE     851735 non-null  object
#  7   NAME_EDUCATION_TYPE  851734 non-null  object
#  8   NAME_FAMILY_STATUS   851733 non-null  object
#  9   NAME_HOUSING_TYPE    851726 non-null  object
#  10  DAYS_BIRTH           851725 non-null  object
#  11  DAYS_EMPLOYED        851720 non-null  object
#  12  FLAG_MOBIL           851716 non-null  object
#  13  FLAG_WORK_PHONE      851711 non-null  object
#  14  FLAG_PHONE           851711 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882350 entries, 0 to 1882349
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   ID              object
#  1   MONTHS_BALANCE  object
#  2   STATUS          object
# dtypes: object(3)
# memory usage: 43.1+ MB

# %%
df.tail()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN  \
# 851730  6840104           M            N               Y            0
# 851731  6840222           F            N               N            0
# 851732  6841878           F            N               N            0
# 851733  6842765           F            N               Y            0
# 851734  6842885           F            N               Y            0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 851730         135000.0             Pensioner  Secondary / secondary special
# 851731         103500.0               Working  Secondary / secondary special
# 851732          54000.0  Commercial associate               Higher education
# 851733          72000.0             Pensioner  Secondary / secondary special
# 851734         121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED  \
# ...

# %%
df2.tail()
# Out:
#               ID MONTHS_BALANCE STATUS
# 1882345  5150487            -25      C
# 1882346  5150487            -26      C
# 1882347  5150487            -27      C
# 1882348  5150487            -28      C
# 1882349  5150487            -29      C

# %%
df.describe()
# Out:
#        CNT_FAM_MEMBERS
# count    851697.000000
# mean          2.194883
# std           0.897211
# min           1.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# max          20.000000

# %%
df2.describe()
# Out:
#              ID  MONTHS_BALANCE   STATUS
# count   1882350       1882348.0  1882340
# unique    51688           128.0        8
# top     5096879            -1.0        C
# freq        122         35762.0   794296

# %%
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         1
# NAME_FAMILY_STATUS          2
# NAME_HOUSING_TYPE           9
# DAYS_BIRTH                 10
# DAYS_EMPLOYED              15
# FLAG_MOBIL                 19
# FLAG_WORK_PHONE            24
# FLAG_PHONE                 24
# FLAG_EMAIL                 28
# OCCUPATION_TYPE        260497
# CNT_FAM_MEMBERS            38
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# ID                 0
# MONTHS_BALANCE     2
# STATUS            10
# dtype: int64

# %%
pd.set_option("display.max_rows",11)
pd.set_option("display.expand_frame_repr",False)

df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED FLAG_MOBIL FLAG_WORK_PHONE FLAG_PHONE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0       5008804           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# 1       5008805           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# ...

# %%
df2
# Out:
#               ID MONTHS_BALANCE STATUS
# 0        5001711            0.0      X
# 1        5001711           -1.0      0
# 2        5001711           -2.0      0
# 3        5001711           -3.0      0
# 4        5001712            0.0      C
# ...          ...            ...    ...
# 1882345  5150487            -25      C
# 1882346  5150487            -26      C
# 1882347  5150487            -27      C
# 1882348  5150487            -28      C
# 1882349  5150487            -29      C
#
# [1882350 rows x 3 columns]

# %%
df.columns = ['ID', 'Gender', 'Own_Car', 'Own_Realty', 'Children', 'Annual_Income', 'Income_Type', 'Education_Level', 'Marital_Status', 'Housing', 'Days_Birth', "Days_Employed", 'Mobile_Phone', 'Work_Phone', 'Phone', 'Email', 'Ocupation', 'Family_Size']

# %%
df.set_index('ID', inplace=True)
df
# Out:
#         CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED FLAG_MOBIL FLAG_WORK_PHONE FLAG_PHONE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# ID
# 5008804           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# 5008805           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED FLAG_MOBIL FLAG_WORK_PHONE FLAG_PHONE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0       5008804           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# 1       5008805           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# ...

# %%
df.index.name = 'Order'
df2.index.name = 'Order'

# %%
df.head()
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE DAYS_BIRTH DAYS_EMPLOYED FLAG_MOBIL FLAG_WORK_PHONE FLAG_PHONE FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# Order
# 0      5008804           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# 1      5008805           M            Y               Y            0         427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542          1               1          0        0.0             NaN              2.0
# ...

# %%
df.index+=1
df2.index+=1

# %%
df2.head()
# Out:
#             ID MONTHS_BALANCE STATUS
# Order
# 1      5001711            0.0      X
# 2      5001711           -1.0      0
# 3      5001711           -2.0      0
# 4      5001711           -3.0      0
# 5      5001712            0.0      C

# %%
df_melted = pd.melt(df, id_vars=['ID'], value_vars=['Mobile_Phone', 'Work_Phone', 'Phone', 'Email'], var_name='Communication', value_name='Y_N')

# %%
df_melted
# Out:
#               ID Communication  Y_N
# 0        5008804  Mobile_Phone    1
# 1        5008805  Mobile_Phone    1
# 2        5008806  Mobile_Phone    1
# 3        5008808  Mobile_Phone    1
# 4        5008809  Mobile_Phone    1
# ...          ...           ...  ...
# 3406935  6840104         Email  0.0
# 3406936  6840222         Email  0.0
# 3406937  6841878         Email  0.0
# 3406938  6842765         Email  0.0
# 3406939  6842885         Email  0.0
#
# [3406940 rows x 3 columns]

# %%
duplicates=df_melted.duplicated()
df_melted[duplicates]
# Out:
#               ID Communication  Y_N
# 65536    6723301  Mobile_Phone  1.0
# 65537    6723302  Mobile_Phone  1.0
# 65538    5114550  Mobile_Phone  1.0
# 65539    5114551  Mobile_Phone  1.0
# 65540    5114552  Mobile_Phone  1.0
# ...          ...           ...  ...
# 3406935  6840104         Email  0.0
# 3406936  6840222         Email  0.0
# 3406937  6841878         Email  0.0
# 3406938  6842765         Email  0.0
# 3406939  6842885         Email  0.0
#
# [1070747 rows x 3 columns]

# %%
#df_unique=df_melted.drop_duplicates()

# %%
df_melted['Y_N']=pd.to_numeric(df_melted['Y_N'], errors='coerce')
df_melted
# Out:
#               ID Communication  Y_N
# 0        5008804  Mobile_Phone  1.0
# 1        5008805  Mobile_Phone  1.0
# 2        5008806  Mobile_Phone  1.0
# 3        5008808  Mobile_Phone  1.0
# 4        5008809  Mobile_Phone  1.0
# ...          ...           ...  ...
# 3406935  6840104         Email  0.0
# 3406936  6840222         Email  0.0
# 3406937  6841878         Email  0.0
# 3406938  6842765         Email  0.0
# 3406939  6842885         Email  0.0
#
# [3406940 rows x 3 columns]

# %%
df_pivot = df_melted.pivot_table(index='ID', columns='Communication', values='Y_N', aggfunc='mean')

# %%
df_pivot
# Out:
# Communication  Email  Mobile_Phone  Phone  Work_Phone
# ID
# 55000.0          NaN           1.0    NaN         NaN
# 5008804          0.0           1.0    0.0         1.0
# 5008805          0.0           1.0    0.0         1.0
# 5008806          0.0           1.0    0.0         0.0
# 5008808          1.0           1.0    1.0         0.0
# ...              ...           ...    ...         ...
# 7999660          0.0           1.0    0.0         0.0
# 7999696          0.0           1.0    0.0         0.0
# 7999738          0.0           1.0    0.0         0.0
# 7999784          0.0           1.0    0.0         0.0
# 7999952          0.0           1.0    0.0         0.0
#
# [513143 rows x 4 columns]

# %%
merged_df = df.merge(df2, on='ID', how='inner')

# %%
merged_df
# Out:
#               ID Gender Own_Car Own_Realty Children Annual_Income Income_Type                Education_Level Marital_Status            Housing Days_Birth Days_Employed Mobile_Phone Work_Phone Phone Email    Ocupation  Family_Size MONTHS_BALANCE STATUS
# 0        5112956      M       Y          Y        0      270000.0     Working               Higher education        Married  House / apartment     -16872          -769            1          1     1   1.0  Accountants          2.0            0.0      X
# 1        5112956      M       Y          Y        0      270000.0     Working               Higher education        Married  House / apartment     -16872          -769            1          1     1   1.0  Accountants          2.0           -1.0      X
# ...

# %%
merged_df2 = df.merge(df2, on='ID', how='outer')

# %%
merged_df2
# Out:
#                                    ID             Gender            Own_Car Own_Realty           Children Annual_Income    Income_Type                Education_Level  Marital_Status            Housing Days_Birth Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size MONTHS_BALANCE STATUS
# 0                                   5                NaN                NaN        NaN                NaN           NaN            NaN                            NaN             NaN                NaN        NaN           NaN          NaN        NaN   NaN   NaN             NaN          NaN              0    NaN
# 1                             55000.0            Working  Incomplete higher      Widow  House / apartment      -19927.0          -3615                              1               0                  0        1.0      Laborers          1.0        NaN   NaN   NaN             NaN          NaN            NaN    NaN
# ...

# %%
concatenated_pd = pd.concat([df,df2], axis=1)

# %%
concatenated_pd
# Out:
#               ID Gender Own_Car Own_Realty Children Annual_Income           Income_Type                Education_Level        Marital_Status            Housing  ... Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation Family_Size       ID MONTHS_BALANCE STATUS
# Order                                                                                                                                                            ...
# 1        5008804      M       Y          Y        0      427500.0               Working               Higher education        Civil marriage   Rented apartment  ...         -4542            1          1     0   0.0             NaN         2.0  5001711            0.0      X
# 2        5008805      M       Y          Y        0      427500.0               Working               Higher education        Civil marriage   Rented apartment  ...         -4542            1          1     0   0.0             NaN         2.0  5001711           -1.0      0
# ...

# %%
result = df[df['Annual_Income'].apply(lambda x: isinstance(x, int))]
result
# Out:
# Empty DataFrame
# Columns: [ID, Gender, Own_Car, Own_Realty, Children, Annual_Income, Income_Type, Education_Level, Marital_Status, Housing, Days_Birth, Days_Employed, Mobile_Phone, Work_Phone, Phone, Email, Ocupation, Family_Size]
# Index: []

# %%
df['Annual_Income']=pd.to_numeric(df['Annual_Income'], errors='coerce')

# %%
result = df[df['Annual_Income'].apply(lambda x: isinstance(x, str))]
result
# Out:
# Empty DataFrame
# Columns: [ID, Gender, Own_Car, Own_Realty, Children, Annual_Income, Income_Type, Education_Level, Marital_Status, Housing, Days_Birth, Days_Employed, Mobile_Phone, Work_Phone, Phone, Email, Ocupation, Family_Size]
# Index: []

# %%
annual_income = df['Annual_Income'].apply(lambda x: x / 12)
annual_income
# Out:
# Order
# 1         35625.0
# 2         35625.0
# 3          9375.0
# 4         22500.0
# 5         22500.0
#            ...
# 851731    11250.0
# 851732     8625.0
# 851733     4500.0
# 851734     6000.0
# 851735    10125.0
# Name: Annual_Income, Length: 851735, dtype: float64

# %%
keys = ['Days_Birth','Days_Employed']
new_df = df[keys]
new_df
# Out:
#        Days_Birth Days_Employed
# Order
# 1          -12005         -4542
# 2          -12005         -4542
# 3          -21474         -1134
# 4          -19110         -3051
# 5          -19110         -3051
# ...           ...           ...
# 851731   -22717.0      365243.0
# 851732   -15939.0       -3007.0
# 851733    -8169.0        -372.0
# 851734   -21673.0      365243.0
# 851735   -18858.0       -1201.0
#
# [851735 rows x 2 columns]

# %%
new_df = new_df.apply(pd.to_numeric,errors='coerce')

# %%
df_year = new_df.applymap(lambda x: x/365)
df_year
# Out:
# <ipython-input-158-ed1ae09174d4>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_year = new_df.applymap(lambda x: x/365)
#         Days_Birth  Days_Employed
# Order
# 1       -32.890411     -12.443836
# 2       -32.890411     -12.443836
# 3       -58.832877      -3.106849
# 4       -52.356164      -8.358904
# 5       -52.356164      -8.358904
# ...            ...            ...
# 851731  -62.238356    1000.665753
# 851732  -43.668493      -8.238356
# 851733  -22.380822      -1.019178
# 851734  -59.378082    1000.665753
# 851735  -51.665753      -3.290411
#
# [851735 rows x 2 columns]

# %%
df['Days_Employed']=pd.to_numeric(df['Days_Employed'], errors='coerce')
unemployed = df.query('Days_Employed < 0')
unemployed
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status            Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size
# Order
# 1       5008804      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0             NaN          2.0
# 2       5008805      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0             NaN          2.0
# ...

# %%
with_parents = df.query('Housing == "With parents"')
with_parents
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status       Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone Phone Email              Ocupation  Family_Size
# Order
# 255     5009078      M       N          Y        1       180000.0               Working  Secondary / secondary special               Married  With parents     -14122        -1286.0            1          0     0   0.0                Drivers          3.0
# 277     5009103      M       Y          Y        2       157500.0               Working  Secondary / secondary special               Married  With parents     -12859        -4056.0            1          0     1   0.0                Drivers          4.0
# ...

# %%
gender_keys = ['Gender', 'Annual_Income']
gender_df = df[gender_keys]
gender_df
# Out:
#        Gender  Annual_Income
# Order
# 1           M       427500.0
# 2           M       427500.0
# 3           M       112500.0
# 4           F       270000.0
# 5           F       270000.0
# ...       ...            ...
# 851731      M       135000.0
# 851732      F       103500.0
# 851733      F        54000.0
# 851734      F        72000.0
# 851735      F       121500.0
#
# [851735 rows x 2 columns]

# %%
for name, group in df.groupby('Marital_Status'):
  print(f"\nGroup: {name}")
  print(group)
# Out:
# Group: -11416
#              ID Gender Own_Car Own_Realty Children  Annual_Income    Income_Type   Education_Level Marital_Status Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone     Phone Email Ocupation  Family_Size
# Order
# 702250  6473058      F       N          Y        1       225000.0  State servant   Sipal apartment         -11416    -247          1            0.0            0          0  Laborers   1.0       NaN          NaN
# 744610  6695608      M       Y          Y        1       112500.0        Working  Seipal apartment         -11416    -247          1            0.0            0          0  Laborers   1.0       NaN          NaN
#
# Group: -14142
#              ID Gender Own_Car Own_Realty Children  Annual_Income Income_Type    Education_Level Marital_Status Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone        Phone Email Ocupation  Family_Size
# Order
# ...

# %%
grouped_gender = gender_df.groupby('Gender').agg({
    'Annual_Income': 'mean'
})
grouped_gender
# Out:
#                    Annual_Income
# Gender
# -2497                   0.000000
# F                  174536.745496
# F180                    0.000000
# F3                           NaN
# House / apartment       1.000000
# M                  214022.770687
# Married                 1.000000
# Working            -19927.000000
# d                       1.000000

# %%
key2 = ['Annual_Income', 'Days_Birth']
income_age = df[key2]
income_age
# Out:
#         Annual_Income Days_Birth
# Order
# 1            427500.0     -12005
# 2            427500.0     -12005
# 3            112500.0     -21474
# 4            270000.0     -19110
# 5            270000.0     -19110
# ...               ...        ...
# 851731       135000.0   -22717.0
# 851732       103500.0   -15939.0
# 851733        54000.0    -8169.0
# 851734        72000.0   -21673.0
# 851735       121500.0   -18858.0
#
# [851735 rows x 2 columns]

# %%
income_age = income_age.apply(pd.to_numeric,errors='coerce')
agg_result = income_age.agg(['mean', 'max', 'min']).astype(int)
agg_result
# Out:
#       Annual_Income  Days_Birth
# mean         187519      -15991
# max        13570000         180
# min          -19927      -25201

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status            Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size
# Order
# 3       5008806      M       Y          Y        0       112500.0               Working  Secondary / secondary special               Married  House / apartment     -21474        -1134.0            1          0     0   0.0  Security staff          2.0
# 4       5008808      F       N          Y        0       270000.0  Commercial associate  Secondary / secondary special  Single / not married  House / apartment     -19110        -3051.0            1          0     1   1.0     Sales staff          1.0
# ...

# %%
df_fillna = df.fillna(9999999999)
df_fillna
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status            Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size
# Order
# 1       5008804      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0      9999999999          2.0
# 2       5008805      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0      9999999999          2.0
# ...

# %%
imputer = SimpleImputer(strategy='mean')

# %%
DF = df
impute_columns = ['Annual_Income', 'Days_Birth', 'Days_Employed', 'Family_Size']
DF = DF.apply(pd.to_numeric,errors='coerce')
result = DF[DF['Days_Birth'].apply(lambda x: isinstance(x, str))]
result
# Out:
# Empty DataFrame
# Columns: [ID, Gender, Own_Car, Own_Realty, Children, Annual_Income, Income_Type, Education_Level, Marital_Status, Housing, Days_Birth, Days_Employed, Mobile_Phone, Work_Phone, Phone, Email, Ocupation, Family_Size]
# Index: []

# %%
DF[impute_columns] = imputer.fit_transform(DF[impute_columns])
df
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status            Housing Days_Birth  Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size
# Order
# 1       5008804      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0             NaN          2.0
# 2       5008805      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005        -4542.0            1          1     0   0.0             NaN          2.0
# ...

# %%
df.isnull().sum()
# Out:
# ID                  0
# Gender              0
# Own_Car             0
# Own_Realty          0
# Children            0
#                 ...
# Work_Phone         24
# Phone              24
# Email              28
# Ocupation      260497
# Family_Size        38
# Length: 18, dtype: int64

# %%
selected_columns = ['Annual_Income', 'Days_Birth', 'Days_Employed', 'Family_Size']
DF[selected_columns].isnull().sum()
# Out:
# Annual_Income    0
# Days_Birth       0
# Days_Employed    0
# Family_Size      0
# dtype: int64

# %%
df
# Out:
#              ID Gender Own_Car Own_Realty Children  Annual_Income           Income_Type                Education_Level        Marital_Status            Housing Days_Birth Days_Employed Mobile_Phone Work_Phone Phone Email       Ocupation  Family_Size
# Order
# 1       5008804      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542            1          1     0   0.0             NaN          2.0
# 2       5008805      M       Y          Y        0       427500.0               Working               Higher education        Civil marriage   Rented apartment     -12005         -4542            1          1     0   0.0             NaN          2.0
# ...

# %% [markdown]
# ## Your task
#
# * Inspect a dataframe with `df.head()`, `df.tail()`, `df.info()`, `df.describe()`.
# * Show how many missing values in your data, each column.
# * Manipulate how a dataframe displays in Jupyter by modifying Pandas configuration options such as `pd.set_option("display.max_rows", n)`.
# * Rename columns of a dataframe using the `df.rename()` function or by accessing the `df.columns` attribute.
# * Modify the index name and index values of a dataframe using `.set_index()`, `.reset_index()` , `df.index.name`, `.index`.
# * Use `df.melt()` and `df.pivot()` to reshape dataframes, specifically to make tidy dataframes.
# * Combine dataframes using `df.merge()` and `pd.concat()` and know when to use these different methods.
# * Apply functions to a dataframe `df.apply()` and `df.applymap()`
# * Find the data which satisfy specific condition using `df.query()`
# * Perform grouping and aggregating operations using `df.groupby()` and `df.agg()`.
# * Perform aggregating methods on grouped or ungrouped objects such as finding the minimum, maximum and sum of values in a dataframe using `df.agg()`.
# * Remove or fill missing values in a dataframe with `df.dropna()` and `df.fillna()` please practice using different method of filling missing value.
# * Practice imputing missing values using the `SimpleImputer` Class in `sklearn`

# %% [markdown]
# ## For extra miles:
#
#
# 1.   clean your text data using regex function
# 2.   clean the text and nested json in https://raw.githubusercontent.com/nnqomariyah/Fundamentals_of_Data_Science/main/week_3/data/movies_metadata.csv
